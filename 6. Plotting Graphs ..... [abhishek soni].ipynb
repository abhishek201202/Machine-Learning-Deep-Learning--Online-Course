# %% [markdown]
# # 1) import module to draw graphs

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 2) scatter points

# %%
x = [1,2,3]
y = [2,4,6]

plt.scatter(x,y)
plt.show()

# %% [markdown]
# # 3) plot points

# %%
x = [1,2,3]
y = [2,4,6]
plt.scatter(x,y)
plt.plot(x,y)
plt.show()

# %%
x = [1,2,3]
y = [2,4,6]

x2 = [3,4,5]
y2 = [2,4,6]
plt.plot(x2,y2)
plt.plot(x,y)
plt.show()

# %% [markdown]
# # 4) scatter ,dash , simple , dash dotted line

# %%
x = [1,2,3]
y = [2,4,6]
# plt.plot(x , y , "r+")
# plt.plot(x , y , "g.")
plt.plot(x , y , "bo") ## scatter line
# plt.plot(x , y , "m--") ## dash line
# plt.plot(x , y , "m-") ## simple line
# plt.plot(x , y , "m+-.") ## dash dotted line
plt.show()

# %% [markdown]
# # 5) plot x^3 function

# %%
import numpy as np
x = np.array([1,2,3,4])
y = x**3
plt.plot(x,y)
plt.show()

# %%
x = np.arange(0,5,0.1) ## create a numpy array whose elements are from 0 to 5 with diff of 0.1
y = x ** 3
plt.plot(x , y , "bo")
plt.show()

# %% [markdown]
# # 6) plot down a single array

# %%
a = [3,4,5] ## treated as the value of y
            ## x should be taken as 0 ,1,2,3,....,n-1
plt.plot(a)
plt.show()

# %% [markdown]
# # 7) color , marker , linewidth ,labels for axis , datasets and the title , axis ,                 grid , text

# %%
x = np.arange(0 , 5 , 0.1)
y = x ** 3
y2 = x ** 2
plt.plot(x , y , color = "green" , marker = "p" , label = "x^3" )
# plt.plot(x , y , color = "red" , linewidth = 5 , label = "x^3" )
plt.plot(x , y2 , color = "black" , linewidth = 5 , label = "x^2")

plt.ylabel("x^3")
plt.xlabel("x")

plt.title("Matplotib demo")

plt.legend()

plt.axis([0,5,0,170])

plt.grid()

plt.text(2 , 80 , "text" , fontsize = 12)

plt.show()

# %% [markdown]
# # 8) pie graph

# %%
sizes = [3 , 4 , 6 , 2]
color = ["blue" , "red" , "orange" , "pink"]
label = ["A" , "B" , "C" , "D"]
explo = [0.1,0,0,0]

plt.pie(sizes , colors = color , labels = label , autopct = "%.2f%%", explode = explo , counterclock = False ) ## to add % add 2 %%
plt.title("spit among classes")
plt.axis("equal")
plt.show()
